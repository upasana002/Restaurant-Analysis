# %% [markdown]
# <a href="https://colab.research.google.com/github/upasana002/Restaurant-Analysis/blob/main/Upasana_Yadav_Cognifyz_Technologies_Internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# RESTAURANT ANALYSIS

# %% [markdown]
# Upasana Yadav
#
# Data Science Internship
#
# December 2023 - January 2024

# %% [markdown]
# **LEVEL 1**

# %% [markdown]
# **TASK 1 : Data Exploration and Preprocessing**
# 1.Explore the dataset and identify the number of rows and columns.
# 2.Check for missing values in each column and handle them accordingly.
# 3.Perform data type conversion if necessary Analyze the distribution of the target variable ("Aggregate rating") and identify any class imbalances.

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading and reading the data
data=pd.read_csv("Data.csv")
data.head(5)
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#Making copy of the data
df=data.copy()
df.head(2)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...          Currency Has Table booking  \
# 0  French, Japanese, Desserts  ...  Botswana Pula(P)               Yes
# 1                    Japanese  ...  Botswana Pula(P)               Yes
#
# ...

# %%
# Display the number of rows & columns.
n_rows , n_columns = df.shape
print("Number of rows : " , n_rows)
print("Number of columns : " , n_columns)
# Out:
# Number of rows :  9551
# Number of columns :  21

# %%
# Check for duplicate rows
dup = df.duplicated()
print('Number of duplicate rows in the dataset: ', dup.sum())
# Out:
# Number of duplicate rows in the dataset:  0

# %%
df.info()
# Data type conversion is npot required
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
# Check missing values
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# Calculate the correlation of missing value in differnt columns.
df.isnull().corr()
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull().corr(),annot=True)
plt.show()

# %%
# Since there is only 9 missing value in cuisine there are two options .
#Either fill it with "Unknown" or drop it .
# I prefer dropping it because filling with unknoen does not make sense here and dropping will not a big difference.
df=df.dropna(subset=['Cuisines'])
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# Distribution of target variable

# %%
# prompt: display rating distribution of  aggregate rating
rating_dist=df['Aggregate rating'].value_counts()
print('Class imbalance : ', rating_dist.max()/rating_dist.min())
df['Aggregate rating'].value_counts().plot(kind='bar')
plt.xlabel('Aggregate rating')
plt.ylabel('Count')
plt.title('Distribution of aggregate rating')
plt.show()
print('Distribution of Aggregate Rating :')
rating_dist
# Out:
# Class imbalance :  2148.0
# Distribution of Aggregate Rating :
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     495
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     399
# 2.9     381
# 3.9     332
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     143
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      41
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %% [markdown]
#  **Observations: Level 1 - Task 1**

# %% [markdown]
# *   The dataset consists of various restaurant information susch as names , cities,address , etc
# *   There are 9551 roews and 21 columns
#
# *   9 null values were present in Cuisines , I have dropped them
# *   Data type conversion is not required
#
# *   The distribution of target variable (Aggregate Rating ) is well balanced . Since the imbalance is not significant , I have not treated it .

# %% [markdown]
# **LEVEL 1 - TASK 2**

# %% [markdown]
# Descriptive Analysis
# Calculate basic statistical measures (mean,
# median, standard deviation, etc.) for numerical
# columns.
# Explore the distribution of categorical
# variables like "Country Code,
# " "City,
# " and
# "Cuisines.
# "
# Identify the top cuisines and cities with the
# highest number of restaurants.

# %%
# Displaying basic statistical measures for numerical columns
numeric_st=df.describe()
print("Descriptive Statistical Measures for Numeric Columns : " )
print(numeric_st)
# Out:
# Descriptive Statistical Measures for Numeric Columns :
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.542000e+03   9542.000000  9542.000000  9542.000000
# mean    9.043301e+06     18.179208    64.274997    25.848532
# std     8.791967e+06     56.451600    41.197602    11.010094
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019312e+05      1.000000    77.081565    28.478658
# 50%     6.002726e+06      1.000000    77.192031    28.570444
# 75%     1.835260e+07      1.000000    77.282043    28.642711
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# ...

# %%
# Display the distribution of 'Country Code'
plt.figure(figsize=(10,8))
df['Country Code'].value_counts().plot(kind='bar',color=['g','r','y','b','orange','violet','brown','pink','black','grey'])
plt.xlabel('Country Code')
plt.ylabel('Count')
plt.title('Distribution of Country Code')
plt.show()
print(df['Country Code'].value_counts())
# Out:
# 1      8652
# 216     425
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64

# %%
# Display the distribution of 'City' using value_counts()
df['City'].value_counts()
# Out:
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# Faridabad          251
# Ghaziabad           25
#                   ...
# Lincoln              1
# Lakeview             1
# Lakes Entrance       1
# Inverloch            1
# Panchkula            1
# Name: City, Length: 140, dtype: int64

# %%
# Display the distribution of 'Cuisines' using value_counts()
df['Cuisines'].value_counts()
# Out:
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
# Identify the top cuisines and cities with the highest number of restaurants.
top_cuisines = df['Cuisines'].value_counts().head(10)
print("Top cuisines with the highest number of restaurants:")
print(top_cuisines)
top_cities = df['City'].value_counts().head(10)
print("Top cities with the highest number of restaurants:")
print(top_cities)
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
df['City'].value_counts().head(10).plot(kind='bar',color=['r','g','b','y','orange','violet','brown','pink','black','grey'])
plt.xlabel('City')
plt.ylabel('Count')
plt.title('Top cities with the highest number of restaurants')
plt.show()
plt.figure(figsize=(10,8))
df['Cuisines'].value_counts().head(10).plot(kind='bar',color=['r','g','b','y','orange','violet','brown','pink','black','grey'])
plt.xlabel('Cuisines')
plt.ylabel('Count')
plt.title('Top cuisines with the highest number of restaurants')
plt.show()
# Out:
# Top cuisines with the highest number of restaurants:
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Name: Cuisines, dtype: int64
# Top cities with the highest number of restaurants:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Amritsar          21
# Bhubaneshwar      21
# Lucknow           21
# Name: City, dtype: int64

# %% [markdown]
# **Observations - Level 1 - Task 2**

# %% [markdown]
# *  Calculated Statistical measures .
# *   Country Code 1 and 216 has highest number of restaurants i.e, 8652 and 425 respectively.
# *   New Delhi is the city with highest number of restaurants.
# *   North Indian and Chinese cuisines are at top with highest number of restaurants.

# %% [markdown]
# **LEVEL 1 - TASK-3 Geospatial Analysis**

# %% [markdown]
# Visualize the locations of restaurants on a
# map using latitude and longitude
# information.
# Analyze the distribution of restaurants
# across different cities or countries.
# Determine if there is any correlation
# between the restaurant's location and its
# rating.

# %%
import geopandas as gpd
from shapely.geometry import Point
# %pip install fiona shapely descartes
#Create a base map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
base=world.plot(figsize=(20,15) , color = 'lightgrey')

#Plot the restaurant Locations.
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
gdf = gpd.GeoDataFrame(df , geometry=geometry)
gdf.plot("Continent" , ax=base , legend=True , figsize=(15,10) , marker = 'o' , color = 'red' , markersize = 16)
# Set the CRS (Coordinate Reference System) - EPSG:4326 is WGS84
gdf.crs = 'EPSG:4326'

#Title
plt.title('Restaurant Locations on World Map')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.show()

# %%
#Count the number of cities with highest number of restaurants and plot

top_cities = df['City'].value_counts().head(10)
top_cities_count = top_cities.values
top_cities_list = top_cities.index
plt.figure(figsize=(10,8))
plt.bar(top_cities_list , top_cities_count)
plt.xlabel('City')
plt.ylabel('Number of restaurants')
plt.title('Top cities with the highest number of restaurants')
plt.show()

# %%
#Aggregate rating base on Latitude and Longitude
location_rating=df.groupby(['Latitude','Longitude'])['Aggregate rating'].mean().reset_index()
#Create a correlation matrix
correlation_matrix=location_rating[['Latitude','Longitude','Aggregate rating']].corr()
#PLot heatmap
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt = ' .2f' , linewidth=0.6)
plt.title('Correlation Matrix : Restaurant Location and Aggregate Rating')
plt.show()

# %% [markdown]
# Observation - Level 1 - Task 3

# %% [markdown]
# *   New Delhi has the most number of restaurants
# *   There is no correlation between (latitude,rating) , longitude & rating are negatively correlated
# *   North America and Asia have the most number of restaurants

# %% [markdown]
# Level 2 - Task 1

# %% [markdown]
#  Table Booking and Online Delivery:
# Determine the percentage of restaurants that
# offer table booking and online delivery.
# Compare the average ratings of restaurants
# with table booking and those without.
# Analyze the availability of online delivery
# among restaurants with different price ranges.

# %%
# Calculating the percentage of restaurants that offer online delivery and offer table booking
booking_percentage=df['Has Table booking'].value_counts(normalize=True)
delivery_percentage=df['Has Online delivery'].value_counts(normalize=True)
plt.figure(figsize=(10,8))
plt.bar(['No','Yes'],[booking_percentage[0],booking_percentage[1]],color=['red','green'])
plt.xlabel('Table Booking')
plt.ylabel('Percentage')
plt.title('Percentage of restaurants with table booking')
plt.show()
plt.figure(figsize=(10,8))
plt.bar(['No','Yes'],[delivery_percentage[0],delivery_percentage[1]],color=['red','green'])
plt.xlabel('Online Delivery')
plt.ylabel('Percentage')
plt.title('Percentage of restaurants with online delivery')
plt.show()
print('Percentage of restaurants with table booking : ',booking_percentage[1]*100)
print('Percentage of restaurants with online delivery : ',delivery_percentage[1]*100)
# Out:
# Percentage of restaurants with table booking :  12.135820582687067
# Percentage of restaurants with online delivery :  25.686438901697755

# %%
#Encoding
df['Has Table booking']=df['Has Table booking'].map({'Yes':1,'No':0})

#calculate average rating for table booking.
avg_rating_with_tb=df[df['Has Table booking']==1]['Aggregate rating'].mean()

#calculate average rating without table booking
avg_rating_without_tb=df[df['Has Table booking']==0]['Aggregate rating'].mean()

print('Average rating for restaurants with table booking: ',avg_rating_with_tb)
print('Average rating for restaurants without table booking: ',avg_rating_without_tb)
# Out:
# Average rating for restaurants with table booking:  3.4419689119170984
# Average rating for restaurants without table booking:  2.557955629770992

# %%
#unique values of average cost for two

df['Average Cost for two'].unique()
# Out:
# array([  1100,   1200,   4000,   1500,   1000,   2000,   6000,    800,
#           900,    700,    850,    600,   3000,   1800,     55,     30,
#            45,     60,     50,     80,     90,    200,    150,    100,
#           230,    240,    350,    140,    170,    120,    250,     40,
#            70,    300,     85,     75,    400,     65,     25,     10,
#             0,     20,     35,      7,    270,    500,    430,    315,
#           220,     95,    190,    260,    180,    330,    280,    160,
#           285,    130,    110,   2500,   3600,    550,   1400,    450,
#           950,    650,   1300,   2400,   1600,   2200,    750,   1700,
#          1250,   1900,   2700,   3500,   5000,   2300,   1750,   3200,
#          2100,   1850,   4500,   3300,   1350,   1650,   1950,   1050,
#           290,   1450,   2800,   3650,   4800,   1550,    720,   6500,
#          7000,   1150,   2900,   2600,   4700,   3700,   3800,   4100,
# ...

# %%
#Calculating availability of online delivery among restaurants with different price ranges
# selecting the price range
price_ranges=df['Average Cost for two'].apply(lambda x:"low" if x < 500 else "medium" if 500 <= x <= 1000 else "high")

online_delivery_by_price_range=df.groupby(price_ranges)['Has Online delivery'].value_counts(normalize=True).unstack()

print('Online Delivery Availability by price ranges :')
print(online_delivery_by_price_range)
# Out:
# Online Delivery Availability by price ranges :
# Has Online delivery         No       Yes
# Average Cost for two
# high                  0.719149  0.280851
# low                   0.858277  0.141723
# medium                0.566209  0.433791

# %% [markdown]
# Online delivery availability for medium price ranges is better than low and high price ranges.

# %% [markdown]
# Level 2 - Task 2

# %% [markdown]
# Task: Price Range Analysis
# Determine the most common price range
# among all the restaurants.
# Calculate the average rating for each price
# range.
# Identify the color that represents the highest
# average rating among different price ranges.

# %%
#Determining the most common price range among all the restaurants.

#count the number of restaurants in each price range
price_range_count=df['Price range'].value_counts()

#plot for count of price range
plt.figure(figsize=(10,8))
plt.bar(price_range_count.index,price_range_count.values,color=['g','r','y','blue'])
plt.xlabel('Price Range')
plt.ylabel('Count')
plt.title('Count of restaurants in each price range')
plt.show()

#find the most common price range
most_common_price_range=price_range_count.idxmax()

print('Most common price range:',most_common_price_range)
# Out:
# Most common price range: 1

# %%
#calculate average rating for each price range
avg_rating_by_price_range=df.groupby('Price range')['Aggregate rating'].mean().reset_index()

#plot the average rating for each price range
plt.figure(figsize=(10,8) )
plt.bar(avg_rating_by_price_range['Price range'],avg_rating_by_price_range['Aggregate rating'])
plt.xlabel('Price Range')
plt.ylabel('Average Rating')
plt.title('Average rating for each price range')
plt.show()

print('Average rating for each price range:')
print(avg_rating_by_price_range)
# Out:
# Average rating for each price range:
#    Price range  Aggregate rating
# 0            1          1.997476
# 1            2          2.941054
# 2            3          3.682633
# 3            4          3.817918

# %%
#unique rating color
print(df['Rating color'].unique())
# Out:
# ['Dark Green' 'Green' 'Yellow' 'Orange' 'White' 'Red']

# %%
df['Rating color'].value_counts()
# Out:
# Orange        3734
# White         2148
# Yellow        2096
# Green         1078
# Dark Green     300
# Red            186
# Name: Rating color, dtype: int64

# %%
#Identify the color that represents the highest average rating among different price ranges.
max_rating = avg_rating_by_price_range['Aggregate rating'].max()
max_rating_price_range = avg_rating_by_price_range[avg_rating_by_price_range['Aggregate rating'] == max_rating]['Price range'].values[0]

print('Price range with highest average rating:', max_rating_price_range)
print('Color representing highest average rating:', df[df['Price range'] == max_rating_price_range]['Rating color'].values[0])
# Out:
# Price range with highest average rating: 4
# Color representing highest average rating: Green

# %% [markdown]
# Level 2 -  Task 3

# %% [markdown]
# Task: Feature Engineering-
# Extract additional features from the existing
# columns, such as the length of the restaurant
# name or address.
# Create new features like "Has Table Booking"
# or "Has Online Delivery" by encoding
# categorical variables.

# %%
df['Restaurant Name Length']=df['Restaurant Name'].apply(len)
df['Address Length']=df['Address'].apply(len)
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#Create new features like "Has Table Booking" or "Has Online Delivery" by encoding categorical variables.
booking_mapping={'No' : 0 , 'Yes' : 1}
delivery_mapping={'No' : 0 , 'Yes' : 1}
df['Has Table booking']=df['Has Table booking'].map(booking_mapping)
df['Has Online delivery']=df['Has Online delivery'].map(delivery_mapping)
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# Level 3 - Task 1

# %% [markdown]
# Task: Predictive Modeling
# -Build a regression model to predict the
# aggregate rating of a restaurant based on
# available features.
# Split the dataset into training and testing sets
# and evaluate the model's performance using
# appropriate metrics.
# Experiment with different algorithms (e.g.,
# linear regression, decision trees, random
# forest) and compare their performance.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
features=['Average Cost for two' , 'Votes' , 'Price range' , 'Has Table booking' , 'Has Online delivery']
target=['Aggregate rating']

X=df[features]
y=df[target]


# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=42 ,  test_size=0.25)

from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
X_train=imputer.fit_transform(X_train)
X_test=imputer.transform(X_test)

# Train the models
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
decision_tree_model = DecisionTreeRegressor()
decision_tree_model.fit(X_train, y_train)
random_forest_model = RandomForestRegressor()
random_forest_model.fit(X_train, y_train)

#Training score
print("Linear Regression training score:", linear_model.score(X_train, y_train))
print("Decision Tree training score:", decision_tree_model.score(X_train, y_train))
print("Random Forest training score:", random_forest_model.score(X_train, y_train))
# Out:
# Linear Regression training score: 0.2538738290217495
# Decision Tree training score: 0.9908031780457592
# Random Forest training score: 0.9849376732293225

# %%
#  create a function to evaluate the above models
def evaluate_models(predictions,y_test,model_name):
  mse=mean_squared_error(y_test,predictions)
  r2=r2_score(y_test,predictions)
  print(f'{model_name} - mse : {mse : .3f} , R2 score : {r2: .3f}')

# %%
# Evaluate the models
linear_model_predictions = linear_model.predict(X_test)
linear_model_mse = mean_squared_error(y_test, linear_model_predictions)
linear_model_r2 = r2_score(y_test, linear_model_predictions)
print('Linear regression MSE:', linear_model_mse)
print('Linear regression R2:', linear_model_r2)
decision_tree_model_predictions = decision_tree_model.predict(X_test)
decision_tree_model_mse = mean_squared_error(y_test, decision_tree_model_predictions)
decision_tree_model_r2 = r2_score(y_test, decision_tree_model_predictions)
print('Decision tree MSE:', decision_tree_model_mse)
print('Decision tree R2:', decision_tree_model_r2)
random_forest_model_predictions = random_forest_model.predict(X_test)
random_forest_model_mse = mean_squared_error(y_test, random_forest_model_predictions)
random_forest_model_r2 = r2_score(y_test, random_forest_model_predictions)
print('Random forest MSE:', random_forest_model_mse)
print('Random forest R2:', random_forest_model_r2)

evaluate_models(linear_model_predictions , y_test , 'Linear Regression')
evaluate_models(decision_tree_model_predictions , y_test , 'Decision Tree')
evaluate_models(random_forest_model_predictions , y_test , 'Random Forest')
# Out:
# Linear regression MSE: 1.6593211142304218
# Linear regression R2: 0.28121008441835604
# Decision tree MSE: 0.2088577804274896
# Decision tree R2: 0.90952633274261
# Random forest MSE: 0.13234398139626682
# Random forest R2: 0.9426708197709637
# Linear Regression - mse :  1.659 , R2 score :  0.281
# Decision Tree - mse :  0.209 , R2 score :  0.910
# Random Forest - mse :  0.132 , R2 score :  0.943

# %% [markdown]
# Random Forest perfoms best for predicting aggregate ratings.
# Decision Tree Regressor also performs well but its less accurate than random forest. Linear regression may not capture the complex relationships present in the data.

# %% [markdown]
# Level 3 - Task 2

# %% [markdown]
# Task: Customer Preference Analysis-
# Analyze the relationship between the type of
# cuisine and the restaurant's rating.
# Identify the most popular cuisines among
# customers based on the number of votes.
# Determine if there are any specific cuisines
# that tend to receive higher ratings.

# %%
#Relationship between Cuisines and Restaurant Ratings
top=15
top_cuisines=df['Cuisines'].value_counts().nlargest(top).index
df_top_cuisines=df[df['Cuisines'].isin(top_cuisines)]
plt.figure(figsize=(15,9))
sns.boxplot(x='Cuisines', y='Aggregate rating' , data=df_top_cuisines , palette='viridis')
plt.xlabel('Cuisines')
plt.ylabel('Aggregate Rating')
plt.xticks(rotation=45)
plt.title('Relationship between Cuisines and Restaurant Ratings')
plt.show()

# %%
#most popular cuisines by number of votes.
top_cuisines = df['Cuisines'].value_counts()
print("Top cuisines with the highest number of votes:")
print(top_cuisines)
df_top_cuisines=df[df['Cuisines'].isin(top_cuisines.head(10).index)]
df_top_cuisines.head()
plt.figure(figsize=(10,8))
df_top_cuisines['Cuisines'].value_counts().head(10).plot(kind='bar',color=['r','g','b','y','orange','violet','brown','pink','black','grey'])
plt.xlabel('Cuisines')
plt.ylabel('Count')
plt.title('Most Popular Cuisines by Number of Votes')
plt.show()
# Out:
# Top cuisines with the highest number of votes:
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: Cuisines, Length: 1825, dtype: int64

# %%
#Determine if there are any specific cuisines that tend to receive higher ratings
# Group by Cuisines and calculate the mean Ratings
cuisine_ratings = df.groupby('Cuisines')['Aggregate rating'].mean().reset_index()

# Sort by Ratings in descending order
sorted_cuisine_ratings = cuisine_ratings.sort_values(by='Aggregate rating', ascending=False)

# Identify cuisines with higher ratings
top_rated_cuisines = sorted_cuisine_ratings.head(10)  # Adjust the number as needed

# Create a bar plot to visualize the ratings of cuisines
plt.figure(figsize=(10, 6))
plt.bar(top_rated_cuisines['Cuisines'], top_rated_cuisines['Aggregate rating'], color='lightgreen')
plt.xlabel('Cuisines')
plt.ylabel('Average Ratings')
plt.title('Cuisines with Higher Ratings')
plt.xticks(rotation=45)
plt.show()

# Print a statement indicating cuisines with higher ratings
print("Cuisines that tend to receive higher ratings are:")
print(top_rated_cuisines)
# Out:
# Cuisines that tend to receive higher ratings are:
#                       Cuisines  Aggregate rating
# 1062             Italian, Deli               4.9
# 949          Hawaiian, Seafood               4.9
# 93     American, Sandwich, Tea               4.9
# 683        Continental, Indian               4.9
# 796    European, Asian, Indian               4.9
# 803     European, Contemporary               4.9
# 808           European, German               4.9
# 169   BBQ, Breakfast, Southern               4.9
# 41    American, Coffee and Tea               4.9
# 1779         Sunda, Indonesian               4.9

# %% [markdown]
# Based on observations , most popular cuisine by number of votes is North Indian . Cuisines like cafe , North Indian,fast food restaurants may perform well with respect to ratings

# %% [markdown]
# Level 3 - Task 3

# %% [markdown]
# Task: Data Visualization -
# Create visualizations to represent the distribution
# of ratings using different charts (histogram, bar
# plot, etc.).
# Compare the average ratings of different cuisines
# or cities using appropriate visualizations.
# Visualize the relationship between various
# features and the target variable to gain insights.

# %%
# Distribution of Ratings
plt.figure(figsize=(10,6))
plt.hist(df['Aggregate rating'], bins=10)
plt.xlabel('Aggregate Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Ratings')
plt.show()
# Plot
plt.figure(figsize=(10,6))
sns.distplot(df['Aggregate rating'])
plt.xlabel('Aggregate Rating')
plt.ylabel('Density')
plt.title('Distribution of Ratings')
plt.show()

# %%
# Group the data by cuisines and calculate the average rating for each cuisine
average_ratings = df.groupby('Cuisines')['Aggregate rating'].mean().sort_values(ascending=False)

# Select the top N cuisines for better visualization
top_n_cuisines=10
top_cuisines=average_ratings.head(top_n_cuisines)

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=top_cuisines.index, y=top_cuisines.values, palette='viridis') # You can choose a different color palette
#Customize the plot
plt.title(f'Top {top_n_cuisines} Cuisines by Average Rating')
plt.xlabel('Cuisine')
plt.ylabel('Average Rating')
plt.xticks(rotation=45, ha='right') # Rotate x-axis Labels for better readability

# Show the plot
plt.show()

# %%
# Group the data by cuisines and calculate the average rating for each cuisine
average_ratings = df.groupby('City')['Aggregate rating'].mean().sort_values(ascending=False)

# Select the top N cuisines for better visualization
top_n_cities=10
top_cities=average_ratings.head(top_n_cities)

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=top_cities.index, y=top_cities.values, palette='viridis') # You can choose a different color palette
#Customize the plot
plt.title(f'Top {top_n_cuisines} Cities by Average Rating')
plt.xlabel('Cities')
plt.ylabel('Average Rating')
plt.xticks(rotation=45, ha='right') # Rotate x-axis Labels for better readability

# Show the plot
plt.show()

# %%
#Visualize the relationship between various features and the target variable to gain insights.
features=['Average Cost for two' , 'Votes' , 'Price range' , 'Has Table booking' , 'Has Online delivery','Aggregate rating']
sns.pairplot(df[features])
plt.show()

# %% [markdown]
# The distributions of restaurants ratings is negatively skewed.
#
# Italian, hawaiian, seafood, tea, sandwich,cpontinental, indian cuisines are most popular inner city,quezon city, makati city etc are most popular cities
#
# Votes and restaurants ratings are positively skewed
